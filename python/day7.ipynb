# %% [markdown]
# 안녕하세요. 수강생 여러분~! Chapter33 ~ 41 수업은 잘 들으셨나요?
#
# Chapter33 ~ 41의 수업 내용을 바탕으로 아래 문제를 풀어주시면 됩니다.
#
#
# <br>
#
#
# [**답변 입력 방법**]
#
# 문제 아래에 있는 코드 입력창에 정답코드를 작성하신 후  __▷ 버튼을 클릭해 코드를 실행__ 해보세요<br>

# %% [markdown]
# ---

# %% [markdown]
# [문제 1]
#
# 사용자로부터 두 개의 숫자를 입력받아 나눗셈을 수행하는 프로그램을 작성하세요.
#
# [예외처리]
# - 입력 값이 숫자가 아닐 때 발생할 수 있는 ValueError
# - 나누는 수가 0일 때 발생할 수 있는 ZeroDivisionError
# - 위 2가지 예외처리 후 사용자에게 이해하기 쉬운 메시지 작성 후 출력되도록 코드를 작성

# %%
try:
    num1, num2 = map(int, input('두 개의 숫자를 입력하세요 (공백으로 구분): ').split(" "))
    print(f'연산 결과는 {num1/num2} 입니다.')
except ValueError:
    print('숫자를 입력해야 합니다.')
except ZeroDivisionError:
    print('0으로 나눌 수 없습니다.')
# Out:
# 연산 결과는 0.6 입니다.

# %% [markdown]
# ---

# %% [markdown]
# [문제 2]
#
# 파일을 읽어서 내용을 출력하는 프로그램을 작성하세요.
#
# - 파일이 존재하지 않을 때 발생하는 FileNotFoundError를 처리
# - 파일이 존재하지 않을 경우 "파일을 찾을 수 없습니다."라는 메시지를 출력

# %%
import os

try:
    os.cat('non_existent_file.txt')
except FileNotFoundError:
    print('파일을 찾을 수 없습니다.')

# %% [markdown]
# ---

# %% [markdown]
# [문제 3]
#
# 사용자로부터 여러 개의 숫자를 입력받아 리스트에 저장한 후, 사용자가 'done'이라고 입력할 때까지 계속 입력받으세요.
#
# - 입력 중 숫자가 아닌 값이 입력되면 ValueError를 처리
# - 숫자 외 값이 입력된 경우 어떤 값이 잘못 입력되었는지 사용자에게 알려주는 문구 출력<br>
#   (예: f"잘못된 값: {변수}. 숫자를 입력해주세요.")

# %%
numbers = []
while True:
    try:
        lstUser = list(map(int, input('숫자 여러 개를 입력하세요.(공백으로 구분, 종료시 done 입력).: ').split(" ")))
        if lstUser == "done":
            break
        numbers.append(int(lstUser))
    except ValueError:
        print(f"입력한 값 '{lstUser}'은(는) 숫자가 아닙니다.)")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 4
#       3 try:
# ----> 4     lstUser = list(map(int, input('숫자 여러 개를 입력하세요.(공백으로 구분, 종료시 done 입력).: ').split(" ")))
#       5     if lstUser == "done":
#
# ValueError: invalid literal for int() with base 10: 'hello'
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 9
#       7     numbers.append(int(lstUser))
#       8 except ValueError:
# ----> 9     print(f"입력한 값 '{lstUser}'은(는) 숫자가 아닙니다.)")
#
# NameError: name 'lstUser' is not defined

# %% [markdown]
# ---

# %% [markdown]
# [문제 4]
#
# 사용자 정의 예외 NegativeNumberError를 생성하고, 사용자로부터 숫자를 입력받아 음수일 경우 NegativeNumberError를 발생시키는 프로그램을 작성하세요.
#
# - 예외 처리 구문을 사용하여 음수 입력 시 "양수를 입력해주세요."라는 메시지를 출력

# %%
#raise

# %% [markdown]
# ---

# %% [markdown]
# [문제 5]
#
# datetime 모듈을 사용하여 현재 날짜와 시간을 출력하는 프로그램을 작성하세요.
#
# 또한, 사용자로부터 태어난 년도를 입력받아 현재 나이를 계산하여 출력하세요.

# %%
import datetime

user_birthYear = input("태어난 년도를 입력하세요: ")
current_year = datetime.datetime.now().year 
age = current_year - int(user_birthYear) + 1   
print(f"당신의 나이는 {age}세 입니다.")
# Out:
# 당신의 나이는 27세 입니다.

# %% [markdown]
# ---

# %% [markdown]
# [문제 6]
#
# requests 모듈을 사용하여, 웹 페이지의 HTML을 가져오는 간단한 웹 스크레이퍼를 작성하세요.
#
# 'https://kream.co.kr/'에서<br>
# 데이터를 가져와서 상태 코드와 HTML의 첫 100자를 출력하세요.<br>
# (실습 전 requests 모듈을 설치해야 함)

# %%
import requests

response = requests.get('https://kream.co.kr')
print("상태 코드:", response.status_code)
print("HTML 내용 (첫 100자):", response.text[:100])
# Out:
# /Users/admin/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# 상태 코드: 500
# HTML 내용 (첫 100자): <!DOCTYPE html>
# <html lang="ko">
# <head>
# <meta name="robots" content="noindex, nofollow" />
# <meta htt

# %% [markdown]
# ---

# %% [markdown]
# [문제 7]
#
# 함수 실행 시간을 측정하는 데코레이터 timer_decorator를 작성하세요.
#
# 임의의 함수가 실행되는 시간을 측정하여 "함수 실행 시간: x.xx초" 형태로 출력하세요.

# %% [markdown]
# ---

# %% [markdown]
# [문제 8]
#
# 여러분이 자주 사용하는 수학적 연산<br>
# (예: 삼각형 넓이, 원의 넓이, 직육면체의 넓이)을 수행하는 함수들을 포함하는 mymath.py라는 이름의 모듈을 만드세요.
#
# 이 모듈을 사용하여 작성된 함수들을 실제로 임포트하고 사용하는 간단한 프로그램을 작성하세요.

# %%
def triangle_area(base, height):
    return 0.5 * base * height

def circle_area(radius):
    return math.pi * radius ** 2

def cuboid_area(length, width, height):
    return 2 * (length * width + width * height + height * length)

# %%
import mymath

print("삼각형 넓이:", mymath.triangle_area(10, 5))
print("원 넓이:", mymath.circle_area(3))
print("직육면체 겉넓이:", mymath.rectangular_prism_area(2, 3, 4))

# %% [markdown]
# ---

# %% [markdown]
# [문제 9]
#
# animals라는 패키지를 만들고, 이 패키지 내에 mammals, birds라는 두 개의 서브 모듈을 생성하세요.
#
# - 각 모듈에는 최소한 한 개 이상의 동물에 관한 클래스를 정의하세요<br>
#   (예: mammals에는 Dog, birds에는 Eagle)
# - 이 패키지와 모듈을 사용하여 동물들의 정보를 출력하는 프로그램을 작성
#
# 폴더 및 파일 구조
# ```
# animals/(폴더)
# ├── __init__.py
# ├── mammals.py
# └── birds.py
# ```

# %% [markdown]
# ---
